# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pycaret[full]

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.0.4'

# %% [markdown]
# DataSet- https://www.kaggle.com/datasets/venky73/spam-mails-dataset?resource=download.
#  This data set helps to find spam emails. it contains two folders of spam and ham. Each folder contains emails

# %%
import pandas as pd
import numpy as np

# %%
#Linking Dataset
df = pd.read_csv('/content/drive/MyDrive/Pycaret_Assignment/spam_ham_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
#using the object base api of pycaret
#Import ClassificationExperiment and init the class

from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
# init setup on exp, our target column is diagnosis
exp.setup(df, target = 'label', session_id = 123)
# Out:
# <style type="text/css">
# #T_4fed2_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4fed2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fed2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4fed2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fed2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4fed2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4fed2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4fed2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4fed2_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4fed2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4fed2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4fed2_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_4fed2_row3_col1" class="data row3 col1" >ham: 0, spam: 1</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4fed2_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_4fed2_row4_col1" class="data row4 col1" >(5171, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4fed2_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_4fed2_row5_col1" class="data row5 col1" >(5171, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4fed2_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_4fed2_row6_col1" class="data row6 col1" >(3619, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4fed2_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_4fed2_row7_col1" class="data row7 col1" >(1552, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4fed2_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4fed2_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4fed2_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_4fed2_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4fed2_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_4fed2_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4fed2_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_4fed2_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4fed2_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_4fed2_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4fed2_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_4fed2_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4fed2_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_4fed2_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4fed2_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_4fed2_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4fed2_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_4fed2_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4fed2_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_4fed2_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4fed2_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_4fed2_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4fed2_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_4fed2_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4fed2_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_4fed2_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4fed2_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_4fed2_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4fed2_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4fed2_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_4fed2_row22_col1" class="data row22 col1" >dce6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best_model = exp.compare_models()
# Out:
# <style type="text/css">
# #T_e8719 th {
#   text-align: left;
# }
# #T_e8719_row0_col0, #T_e8719_row1_col0, #T_e8719_row2_col0, #T_e8719_row2_col2, #T_e8719_row3_col0, #T_e8719_row4_col0, #T_e8719_row5_col0, #T_e8719_row5_col1, #T_e8719_row5_col3, #T_e8719_row5_col5, #T_e8719_row5_col6, #T_e8719_row5_col7, #T_e8719_row6_col0, #T_e8719_row6_col1, #T_e8719_row6_col3, #T_e8719_row6_col5, #T_e8719_row6_col6, #T_e8719_row6_col7, #T_e8719_row7_col0, #T_e8719_row7_col1, #T_e8719_row7_col3, #T_e8719_row7_col5, #T_e8719_row7_col6, #T_e8719_row7_col7, #T_e8719_row8_col0, #T_e8719_row8_col1, #T_e8719_row8_col2, #T_e8719_row8_col3, #T_e8719_row8_col5, #T_e8719_row8_col6, #T_e8719_row8_col7, #T_e8719_row9_col0, #T_e8719_row9_col1, #T_e8719_row9_col3, #T_e8719_row9_col5, #T_e8719_row9_col6, #T_e8719_row9_col7, #T_e8719_row10_col0, #T_e8719_row10_col1, #T_e8719_row10_col3, #T_e8719_row10_col5, #T_e8719_row10_col6, #T_e8719_row10_col7, #T_e8719_row11_col0, #T_e8719_row11_col1, #T_e8719_row11_col3, #T_e8719_row11_col4, #T_e8719_row11_col5, #T_e8719_row11_col6, #T_e8719_row11_col7, #T_e8719_row12_col0, #T_e8719_row12_col1, #T_e8719_row12_col2, #T_e8719_row12_col3, #T_e8719_row12_col4, #T_e8719_row12_col5, #T_e8719_row12_col6, #T_e8719_row12_col7, #T_e8719_row13_col0, #T_e8719_row13_col1, #T_e8719_row13_col2, #T_e8719_row13_col3, #T_e8719_row13_col4, #T_e8719_row13_col5, #T_e8719_row13_col6, #T_e8719_row13_col7, #T_e8719_row14_col0, #T_e8719_row14_col1, #T_e8719_row14_col2, #T_e8719_row14_col3, #T_e8719_row14_col4, #T_e8719_row14_col5, #T_e8719_row14_col6, #T_e8719_row14_col7, #T_e8719_row15_col0, #T_e8719_row15_col1, #T_e8719_row15_col2, #T_e8719_row15_col3, #T_e8719_row15_col4, #T_e8719_row15_col5, #T_e8719_row15_col6, #T_e8719_row15_col7 {
#   text-align: left;
# }
# #T_e8719_row0_col1, #T_e8719_row0_col2, #T_e8719_row0_col3, #T_e8719_row0_col4, #T_e8719_row0_col5, #T_e8719_row0_col6, #T_e8719_row0_col7, #T_e8719_row1_col1, #T_e8719_row1_col2, #T_e8719_row1_col3, #T_e8719_row1_col4, #T_e8719_row1_col5, #T_e8719_row1_col6, #T_e8719_row1_col7, #T_e8719_row2_col1, #T_e8719_row2_col3, #T_e8719_row2_col4, #T_e8719_row2_col5, #T_e8719_row2_col6, #T_e8719_row2_col7, #T_e8719_row3_col1, #T_e8719_row3_col2, #T_e8719_row3_col3, #T_e8719_row3_col4, #T_e8719_row3_col5, #T_e8719_row3_col6, #T_e8719_row3_col7, #T_e8719_row4_col1, #T_e8719_row4_col2, #T_e8719_row4_col3, #T_e8719_row4_col4, #T_e8719_row4_col5, #T_e8719_row4_col6, #T_e8719_row4_col7, #T_e8719_row5_col2, #T_e8719_row5_col4, #T_e8719_row6_col2, #T_e8719_row6_col4, #T_e8719_row7_col2, #T_e8719_row7_col4, #T_e8719_row8_col4, #T_e8719_row9_col2, #T_e8719_row9_col4, #T_e8719_row10_col2, #T_e8719_row10_col4, #T_e8719_row11_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e8719_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_e8719_row1_col8, #T_e8719_row2_col8, #T_e8719_row3_col8, #T_e8719_row4_col8, #T_e8719_row5_col8, #T_e8719_row6_col8, #T_e8719_row7_col8, #T_e8719_row8_col8, #T_e8719_row9_col8, #T_e8719_row10_col8, #T_e8719_row11_col8, #T_e8719_row12_col8, #T_e8719_row13_col8, #T_e8719_row14_col8, #T_e8719_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e8719" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8719_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e8719_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e8719_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e8719_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e8719_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e8719_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e8719_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e8719_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e8719_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8719_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_e8719_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_e8719_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_e8719_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_e8719_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_e8719_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_e8719_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_e8719_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_e8719_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_e8719_row0_col8" class="data row0 col8" >0.4480</td>
#     </tr>
#     <tr>
#       <th id="T_e8719_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_e8719_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_e8719_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_e8719_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_e8719_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_e8719_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_e8719_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_e8719_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_e8719_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_e8719_row1_col8" class="data row1 col8" >0.5160</td>
#     </tr>
#     <tr>
#       <th id="T_e8719_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_e8719_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_e8719_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_e8719_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_e8719_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_e8719_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_e8719_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_e8719_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_e8719_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_e8719_row2_col8" class="data row2 col8" >0.6250</td>
#     </tr>
#     <tr>
#       <th id="T_e8719_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_e8719_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_e8719_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_e8719_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_e8719_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_e8719_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_e8719_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_e8719_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_e8719_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_e8719_row3_col8" class="data row3 col8" >0.9960</td>
#     </tr>
#     <tr>
#       <th id="T_e8719_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_e8719_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_e8719_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_e8719_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_e8719_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_e8719_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_e8719_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_e8719_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_e8719_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_e8719_row4_col8" class="data row4 col8" >2.7470</td>
#     </tr>
#     <tr>
#       <th id="T_e8719_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_e8719_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_e8719_row5_col1" class="data row5 col1" >0.9997</td>
#       <td id="T_e8719_row5_col2" class="data row5 col2"
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
best_model
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#evaluate_model function to analyzes the performance of a trained model on the test set
exp.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
exp.plot_model(best_model, plot = 'confusion_matrix')

# %%
nb_model = exp.create_model('nb')
# Out:
# <style type="text/css">
# #T_40079_row10_col0, #T_40079_row10_col1, #T_40079_row10_col2, #T_40079_row10_col3, #T_40079_row10_col4, #T_40079_row10_col5, #T_40079_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_40079" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40079_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_40079_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_40079_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_40079_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_40079_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_40079_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_40079_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40079_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_40079_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_40079_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_40079_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_40079_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_40079_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_40079_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40079_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_40079_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_40079_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_40079_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_40079_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_40079_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_40079_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40079_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_40079_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_40079_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_40079_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_40079_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_40079_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_40079_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40079_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_40079_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_40079_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_40079_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_40079_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_40079_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_40079_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40079_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_40079_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_40079_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_40079_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_40079_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_40079_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_40079_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40079_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_40079_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_40079_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_40079_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_40079_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_40079_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_40079_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40079_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_40079_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_40079_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_40079_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_40079_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_40079_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_40079_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40079_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_40079_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_40079_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_40079_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_40079_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_40079_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_40079_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40079_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_40079_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_40079_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_40079_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_40079_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_40079_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_40079_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40079_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_40079_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_40079_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_40079_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_40079_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_40079_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_40079_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_40079_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_40079_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_40079_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_40079_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_40079_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_40079_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_40079_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_40079_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_40079_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_40079_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_40079_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_40079_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_nb_model = exp.tune_model(nb_model)
# Out:
# <style type="text/css">
# #T_2b666_row10_col0, #T_2b666_row10_col1, #T_2b666_row10_col2, #T_2b666_row10_col3, #T_2b666_row10_col4, #T_2b666_row10_col5, #T_2b666_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2b666" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b666_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2b666_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2b666_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2b666_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2b666_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2b666_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2b666_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b666_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b666_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_2b666_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_2b666_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_2b666_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_2b666_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_2b666_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_2b666_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b666_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_2b666_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_2b666_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_2b666_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_2b666_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_2b666_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_2b666_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b666_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_2b666_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_2b666_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_2b666_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_2b666_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_2b666_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_2b666_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b666_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_2b666_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_2b666_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_2b666_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_2b666_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_2b666_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_2b666_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b666_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_2b666_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_2b666_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_2b666_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_2b666_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_2b666_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_2b666_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b666_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_2b666_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_2b666_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_2b666_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_2b666_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_2b666_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_2b666_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b666_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_2b666_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_2b666_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_2b666_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_2b666_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_2b666_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_2b666_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b666_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_2b666_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_2b666_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_2b666_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_2b666_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_2b666_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_2b666_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b666_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_2b666_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_2b666_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_2b666_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_2b666_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_2b666_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_2b666_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b666_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_2b666_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_2b666_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_2b666_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_2b666_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_2b666_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_2b666_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2b666_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_2b666_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_2b666_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_2b666_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_2b666_row10_col4" class="data row10 col4" >1.0000</td>
#       <td id="T_2b666_row10_col5" class="data row10 col5" >1.0000</td>
#       <td id="T_2b666_row10_col6" class="data row10 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b666_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2b666_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_2b666_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_2b666_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_2b666_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
! mkdir -p /content/drive/MyDrive/DM/Assignment2/PyCaretBinaryClassifiation/

# %%
#exporting the model as file
exp.save_model(tuned_nb_model, '/content/drive/MyDrive/Pycaret_Assignment')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Unnamed: 0', 'label_num'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missin...
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('clean_column_names',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   GaussianNB(priors=None, var_smoothing=1e-09))],
#           verbose=False),
#  '/content/drive/MyDrive/Pycaret_Assignment.pkl')

# %% [markdown]
# Using the saved model to make predictions further

# %%
#reading the saved pipeline and using it to make prediction on the entire data
from pycaret.classification import load_model,predict_model

# %%
model
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Unnamed: 0', 'label_num'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missin...
#                                                               drop_invariant=False,
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               hierarchy=None,
#                                                               min_samples_leaf=20,
#                                                               return_df=True,
#                                                               smoothing=10,
#                                                               verbose=0))),
#                 ('clean_column_names',
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                 ('trained_model',
#                  GaussianNB(priors=None, var_smoothing=1e-09))],
#          verbose=False)

# %%
#using this model to make prediction on the entire dataset
data =df.copy()
data.drop(['label'],axis=1,inplace=True)

# %%
model = load_model('/content/drive/MyDrive/Pycaret_Assignment')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predictions = predict_model(model,data)#predicting Data

# %%
predic

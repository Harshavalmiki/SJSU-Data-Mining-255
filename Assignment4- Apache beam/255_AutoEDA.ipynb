# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavalmiki/SJSU-Data-Mining-255/blob/main/255_AutoEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Auto EDA**-
# EDA involves analyzing data to find patterns that can be used to verify hypotheses, detect anomalies and complete other actions.

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# DataSet-https://www.kaggle.com/datasets/neuromusic/avocado-prices/

# %%
d=pd.read_csv('/content/gdrive/MyDrive/Apache/avocado.csv')
d.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
pip install sweetviz

# %%
import sweetviz as sv
hotelsfeedback_report = sv.analyze(d)
hotelsfeedback_report.show_html('analyze.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report analyze.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
d1 = pd.read_csv('/content/gdrive/MyDrive/Apache/Top 14 Ever Most Viewed YouTube Videos.csv')

# %%
d1.head(2)
# Out:
#                                         Video Name  \
# 0         Masha and The Bear - Recipe For Disaster
# 1  Johny Johny Yes Papa - Great Songs for Children
#
#                                         Channel Name       Views Likes  \
# 0                                 Masha and The Bear   561185827  2.1M
# 1  LooLoo Kids - Nursery Rhymes and Children's Songs  1020807584  3.2M
#
#   Uploading Date Duration        Description
# 0      14-Aug-15  0:06:42       Kids Cartoon
# 1      15-Jan-17  0:55:18  Kids Cartoon Song

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Video Name      14 non-null     object
#  1   Channel Name    14 non-null     object
#  2   Views           14 non-null     int64
#  3   Likes           14 non-null     object
#  4   Uploading Date  14 non-null     object
#  5   Duration        14 non-null     object
#  6   Description     14 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 912.0+ bytes

# %%
training = d1[:5]
testing = d1[5:]
comparison_report = sv.compare(training,testing)
comparison_report.show_html('Compare.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Compare.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
compare_internal_column = sv.compare_intra(d1,d1['Channel Name'] == 'Masha and The Bear',['Masha and The Bear','Other'])
compare_internal_column.show_html('internal_column.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report internal_column.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
